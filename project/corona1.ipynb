# %%
import pandas as pd

# %%
import pandas_profiling

# %%
import seaborn as sns

# %%
a = pd.read_csv(r'C:\Users\LENOVO\Desktop\New_York_City_Leading_Causes_of_Death.csv')
a.head(50)
# Out:
#     Year                                      Leading Cause Sex  \
# 0   2010            Influenza (Flu) and Pneumonia (J09-J18)   F
# 1   2008  Accidents Except Drug Posioning (V01-X39, X43,...   F
# 2   2013  Accidents Except Drug Posioning (V01-X39, X43,...   M
# 3   2010          Cerebrovascular Disease (Stroke: I60-I69)   M
# 4   2009                 Assault (Homicide: Y87.1, X85-Y09)   M
# 5   2012  Mental and Behavioral Disorders due to Acciden...   F
# 6   2012          Cerebrovascular Disease (Stroke: I60-I69)   F
# 7   2009  Essential Hypertension and Renal Diseases (I10...   M
# 8   2010                                   All Other Causes   F
# 9   2009                          Alzheimer's Disease (G30)   F
# 10  2013          Cerebrovascular Disease (Stroke: I60-I69)   M
# 11  2011          Cerebrovascular Disease (Stroke: I60-I69)   F
# 12  2012     Diseases of Heart (I00-I09, I11, I13, I20-I51)   F
# 13  2013    Intentional Self-Harm (Suicide: X60-X84, Y87.0)   M
# ...

# %%
a.isna().describe()
# Out:
#          Year Leading Cause    Sex Race Ethnicity Deaths Death Rate  \
# count    1094          1094   1094           1094   1094       1094
# unique      1             1      1              1      1          1
# top     False         False  False          False  False      False
# freq     1094          1094   1094           1094   1094       1094
#
#        Age Adjusted Death Rate
# count                     1094
# unique                       1
# top                      False
# freq                      1094

# %%
sns.heatmap(a.isnull(),cbar=False,cmap='viridis')

# %%
a.duplicated(['Leading Cause'])
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1089     True
# 1090     True
# 1091     True
# 1092     True
# 1093     True
# Length: 1094, dtype: bool

# %%
pandas_profiling.ProfileReport(a)
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.2.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...

# %%
len(a)
# Out:
# 1094

# %%
a.columns
# Out:
# Index(['Year', 'Leading Cause', 'Sex', 'Race Ethnicity', 'Deaths',
#        'Death Rate', 'Age Adjusted Death Rate'],
#       dtype='object')

# %%
a.groupby('Sex')[['Deaths']].count()
# Out:
#      Deaths
# Sex
# F       554
# M       540

# %%
decade = 10*(a['Year']/10)
decade
# Out:
# 0       2010.0
# 1       2008.0
# 2       2013.0
# 3       2010.0
# 4       2009.0
#          ...
# 1089    2012.0
# 1090    2014.0
# 1091    2009.0
# 1092    2009.0
# 1093    2013.0
# Name: Year, Length: 1094, dtype: float64

# %%
decade = decade.astype(str)+'s'
decade
# Out:
# 0       2010.0s
# 1       2008.0s
# 2       2013.0s
# 3       2010.0s
# 4       2009.0s
#          ...
# 1089    2012.0s
# 1090    2014.0s
# 1091    2009.0s
# 1092    2009.0s
# 1093    2013.0s
# Name: Year, Length: 1094, dtype: object

# %%
decade.name = 'decade'
a.groupby(['Sex',decade])['Deaths'].count().unstack().fillna(0)
# Out:
# decade  2007.0s  2008.0s  2009.0s  2010.0s  2011.0s  2012.0s  2013.0s  2014.0s
# Sex
# F            73       67       69       69       72       68       66       70
# M            68       69       66       69       69       66       67       66

# %%
decade.name = 'decade'
a.groupby(['Leading Cause',decade])['Sex'].count().unstack().fillna(0)
# Out:
# decade                                              2007.0s  2008.0s  2009.0s  \
# Leading Cause
# Accidents Except Drug Posioning (V01-X39, X43, ...     12.0     11.0      9.0
# All Other Causes                                       12.0     12.0     12.0
# Alzheimer's Disease (G30)                               2.0      1.0      6.0
# Aortic Aneurysm and Dissection (I71)                    1.0      1.0      0.0
# Assault (Homicide: Y87.1, X85-Y09)                      5.0      3.0      2.0
# Atherosclerosis (I70)                                   1.0      0.0      1.0
# Cerebrovascular Disease (Stroke: I60-I69)              11.0     11.0     11.0
# Certain Conditions originating in the Perinatal...      2.0      4.0      4.0
# Chronic Liver Disease and Cirrhosis (K70, K73)          4.0      4.0      4.0
# Chronic Lower Respiratory Diseases (J40-J47)           11.0     11.0     11.0
# Congenital Malformations, Deformations, and Chr...      1.0      1.0      1.0
# ...

# %%
a.groupby(['Year']).count()
# Out:
#       Leading Cause  Sex  Race Ethnicity  Deaths  Death Rate  \
# Year
# 2007            141  141             141     141         141
# 2008            136  136             136     136         136
# 2009            135  135             135     135         135
# 2010            138  138             138     138         138
# 2011            141  141             141     141         141
# 2012            134  134             134     134         134
# 2013            133  133             133     133         133
# 2014            136  136             136     136         136
#
#       Age Adjusted Death Rate
# Year
# 2007                      141
# 2008                      136
# 2009                      135
# 2010                      138
# 2011                      141
# 2012                      134
# 2013                      133
# 2014                      136

# %%
decade.name = 'decade'
a.groupby(['Sex',decade])[['Leading Cause']].count().unstack().fillna(0)
# Out:
#        Leading Cause
# decade       2007.0s 2008.0s 2009.0s 2010.0s 2011.0s 2012.0s 2013.0s 2014.0s
# Sex
# F                 73      67      69      69      72      68      66      70
# M                 68      69      66      69      69      66      67      66

# %%
from sklearn.linear_model import LinearRegression

# %%
x=a[['Year']]

# %%
y=a['Deaths']

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)

# %%
slr=LinearRegression()

# %%
a['Year']= a['Year'].astype(float)
a['Year'].dtype
# Out:
# dtype('float64')

# %%
a['Deaths'].replace('.',0,inplace=True)

# %%
a['Deaths'] = a['Deaths'].astype(int)

# %%
a['Deaths'].dtype
# Out:
# dtype('int32')

# %%
x= a[['Deaths']]

# %%
y= a['Year']

# %%
slr.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
slr.coef_
# Out:
# array([5.0814455e-06])

# %%
import scipy

# %%
slr.intercept_
# Out:
# 2010.4751740364024

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.plot(x,slr.intercept_+slr.coef_*x,'r')

# %%
slr.score(x,y)
# Out:
# 3.4295277862028684e-06

# %%
import numpy as np
x = pd.DataFrame({'a':[1,np.nan,None,3],
                 'b':['hello',' ',np.nan,3],
                 'c':[5,6,np.nan,9]},
                columns=['a','b','c',])

# %%
x
# Out:
#      a      b    c
# 0  1.0  hello  5.0
# 1  NaN         6.0
# 2  NaN    NaN  NaN
# 3  3.0      3  9.0

# %%
sns.heatmap(x.isnull(),cbar=False,cmap='inferno')
